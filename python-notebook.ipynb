# %%
print ("Welcome to Python\n")
fname=input ("Please enter your first name\n")
sname=input ("Please enter your surname\n")
print ("Welcome \n",fname,sname)
# Out:
# Welcome to Python
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_38/2017906972.py in <module>
#       1 print ("Welcome to Python\n")
# ----> 2 fname=input ("Please enter your first name\n")
#       3 sname=input ("Please enter your surname\n")
#       4 print ("Welcome \n",fname,sname)
#       5
#
# /opt/conda/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1078             self._parent_ident["shell"],
#    1079             self.get_parent("shell"),
# -> 1080             password=False,
#    1081         )
#    1082
#
# /opt/conda/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1119             except KeyboardInterrupt:
#    1120                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
#  ## **Welcome to the course**
#  ####  *A new para break*
#
#  >To begin -
#  + Python is case sensitive
#  + Python needs correct spacing and indents (Tab)
#  + \n means start a new line
#  + Types (number, string, bolean, list,tuples)
#  + \*\= Multiply, /= True Division, //= Integer division, % = Modulus
#  + Variables are assigned with a single = equals sign
#  + To check if something is equal, two equal signs are used two==2

# %% [markdown]
# > Types of Errors -
# + Logical error
# + Syntax error
# + Type error

# %%
## Trust Fund Buddy - Bad
# Demonstrates a logical error

print(
    """
    Trust fund buddy
Totals monthly spending

Please enter the requested below
"""
)
car=input("Lamborghini Tune-Up: ")
rent=input("Manhattan apartment")
jet=input("Private Jet rental")
gifts=input("Gifts: ")
food=input("Dining out :")
staff=input("Staff: ")
guru=input("Personal Guru :")
games=input("Computer games")
total=car+rent+jet+gifts+food+staff+guru+games
print("\nGrand Total: ")
input("\nPess any key to exit")
# Out:
#     Trust fund buddy
# Totals monthly spending
#
# Please enter the requested below
# Lamborghini Tune-Up:  566
# Manhattan apartment 58
# Private Jet rental 568588
# Gifts:  474
# Dining out : 4676
# Staff:  578
# Personal Guru : 67986
# Computer games 679
# Grand Total:
# Pess any key to exit
# ''

# %% [markdown]
# Watch out for Operator overloading!
